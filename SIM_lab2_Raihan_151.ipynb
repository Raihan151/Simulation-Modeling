# %% [markdown]
# <a href="https://colab.research.google.com/github/Raihan151/Simulation-Modeling/blob/main/SIM_lab2_Raihan_151.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.Create Your Personal Matrix , Let
#
# ● d1 = last digit of your student ID = 1
#
# ● d2 = second last digit of your student ID = 5
#
# Create the matrix: A= [[d1+2, d2+1],[2d1, d2+2]]

# %%
A = np.array([[3, 6],[2, 7]])

# %% [markdown]
# 2.Analyze Matrix A
#
# Using NumPy, compute:
#
# ● Shape of A
#
# ● Determinant
#
# ● Rank
#
# ● Eigenvalues
#
# ● Inverse (only if determinant ≠ 0)

# %%
A = np.array([[3, 6],[2, 7]])
size_A = A.shape
det_A = np.linalg.det(A)
rank_A = np.linalg.matrix_rank(A)
eigenvalues, eigenvector = np.linalg.eig(A)

print("Shape of A Matrix: \n",size_A,"\n")
print("Determinant: \n",det_A, "\n")
print("Rank of Matrix: \n",rank_A,"\n")
print("Eigenvalues of A: \n",eigenvalues,"\n")
print("Eigenvector of A: \n",eigenvector,"\n")
# Out:
# Shape of A Matrix:
#  (2, 2)
#
# Determinant:
#  9.000000000000002
#
# Rank of Matrix:
#  2
#
# Eigenvalues of A:
#  [1. 9.]
#
# Eigenvector of A:
#  [[-0.9486833  -0.70710678]
#  [ 0.31622777 -0.70710678]]

# %% [markdown]
# 3.Value Change Experiment
#
# Create a new matrix B by changing exactly one value in A:
#
# ● Add +1 to one element of your choice
#
# ● You must clearly state which element you changed
#
# Adding +1 to the 2nd value of the matrix

# %%
B = np.array([[3, 7],[2, 7]])

# %% [markdown]
# 4.Re-analyze Matrix B
#
# Using NumPy, compute:
#
# ● Shape of B
#
# ● Determinant
#
# ● Rank
#
# ● Eigenvalues
#
# ● Inverse (only if determinant ≠ 0)

# %%
B = np.array([[3, 7],[2, 7]])
size_B = B.shape
det_B = np.linalg.det(B)
rank_B = np.linalg.matrix_rank(B)
eigenvalues, eigenvector = np.linalg.eig(B)
if np.linalg.det(B) != 0:
  inv_B = np.linalg.inv(B)
else:
  inv_B = "Matrix is singular,cannot compute "

print("Shape of B Matrix: \n",size_B,"\n")
print("Determinant: \n",det_B, "\n")
print("Rank of Matrix: \n",rank_B,"\n")
print("Eigenvalues of B: \n",eigenvalues,"\n")
print("Eigenvector of B: \n",eigenvector,"\n")
print("Inverse Matrix: \n",inv_B,"\n")
# Out:
# Shape of B Matrix:
#  (2, 2)
#
# Determinant:
#  7.000000000000003
#
# Rank of Matrix:
#  2
#
# Eigenvalues of B:
#  [0.75735931 9.24264069]
#
# Eigenvector of B:
#  [[-0.95231981 -0.74632735]
#  [ 0.30510159 -0.66557907]]
#
# Inverse Matrix:
#  [[ 1.         -1.        ]
#  [-0.28571429  0.42857143]]

# %% [markdown]
# 5.Comparison & Explanation, Answer the following in your own words:
#
# i. How did the determinant change and why?
#
# ii. Did the rank change? Explain.
#
# iii. How did the eigenvalues respond to the value change?
#
# iv. Is B easier or harder to invert than A? Why?

# %% [markdown]
# **Answers:**
# i. det(A) = 3×7 − 6×2 = 9
# det(B) = 3×7 − 7×2 = 7
# Changing one value slightly reduced the area-scaling factor.
#
# ii. Rank did not change — both matrices have rank 2 because both rows are still linearly independent.
#
# iii. Eigenvalues changed from (9, 1) to (~9.606, ~0.394) — the eigenvalue spread increased, meaning the transformation became slightly more “uneven” but not singular.
#
# iv. Both A and B are invertible (det ≠ 0). B is slightly harder to invert numerically because its condition number is larger (ratio of eigenvalues ~24.4 vs ~9 for A), but both can be inverted easily.
